# %%
# ch 7 web scraping - 13%
# ch 8 Django - 12%

# %%
import requests 
from bs4 import BeautifulSoup

# %%
website = "https://subslikescript.com/movie/Titanic-120338"
result = requests.get(website)
content = result.text
soup = BeautifulSoup(content, 'html.parser')
# print(soup.prettify())

# %%
title = soup.find("h1").text
title
# Out:
# 'Titanic (1997) - full transcript'

# %%
title = soup.find("p").text
title
# Out:
# 'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.'

# %%
transcript = soup.find("div", class_='full-script').text
# transcript

# %%
with open('titanic.txt','w',encoding='utf-8') as file:
    file.write(transcript)

# %%
website = "https://subslikescript.com/movies"
result = requests.get(website)
content = result.text
soup = BeautifulSoup(content, 'html.parser')
box = soup.find("article")
movie_title=box.find_all('a')
movie_name=[]
for i in movie_title:
    movie_name.append(i.text.strip())
# movie_name

# %%
links=[]
for i in box.find_all('a'):
    links.append(i['href'])
url="https://subslikescript.com"
for i in links:
    website = url+i
    result = requests.get(website)
    content = result.text
    soup = BeautifulSoup(content, 'html.parser')
    transcript = soup.find("div", class_='full-script').text
    title = soup.find("h1").text.strip()
    with open(title+'.txt','w',encoding='utf-8') as file:
        file.write(transcript)

# %%
website = "https://www.bbc.com/news"
result = requests.get(website)
content = result.text
soup = BeautifulSoup(content, 'html.parser')
news=soup.find('div',class_="sc-cd6075cf-0 eEpsRw")
news_title=news.find_all('h2')
for i in news_title:
    print(i.text.strip())
# Out:
# Selling children to survive: Afghan fathers forced to make impossible choices
# Teen suspects fatally shoot three in suspected hate crime at San Diego mosque
# Starbucks Korea sacks CEO over controversial 'Tank Day' promotion
# Tasmanian government apologises over stolen body parts scandal
# At least 131 dead in Ebola outbreak in DR Congo, official says
# Trump told Taiwan not to 'go independent' - but does it want to?
# What really holds China and Russia together
# 'FedEx says your parcel has drugs': The scam that trapped an Indian comedian

# %%
import pandas as pd
website = "https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops"
result = requests.get(website)
content = result.text
soup = BeautifulSoup(content, 'html.parser')
box=soup.find_all('div',class_="card thumbnail")
names=[]
prices=[]
for i in box:
    names.append(i.find('a',class_='title').text.strip())
    prices.append(i.find('span').text.strip())
laptop={'name':names, 'price':prices}
df=pd.DataFrame(leptop)
df.to_csv('laptop.csv',index=False)
